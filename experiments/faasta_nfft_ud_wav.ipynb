# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg

# Third party import
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import imread
import scipy.io
from tqdm import tqdm_notebook

# Package import
from modopt.math.metrics import ssim
from modopt.opt.linear import Identity
from modopt.opt.proximity import SparseThreshold, LinearCompositionProx, LinearCompositionIterativeProx
from mri.numerics.fourier import FFT2, NFFT
from mri.numerics.gradient import GradAnalysis2
from mri.numerics.linear import Wavelet2, WaveletUD
from mri.numerics.reconstruct import sparse_rec_fista
from mri.numerics.utils import convert_mask_to_locations
import pysap
from pysap.data import get_sample_data

np.random.seed(0)
# Out:
#                  .|'''|       /.\      '||'''|,
#                  ||          // \\      ||   ||
# '||''|, '||  ||` `|'''|,    //...\\     ||...|'
#  ||  ||  `|..||   .   ||   //     \\    ||
#  ||..|'      ||   |...|' .//       \\. .||
#  ||       ,  |'
# .||        ''
#
# Package version: 0.0.3
#
# License: CeCILL-B
#
# Authors:
#
# Antoine Grigis <antoine.grigis@cea.fr>
# Samuel Farrens <samuel.farrens@cea.fr>
# Jean-Luc Starck <jl.stark@cea.fr>
# Philippe Ciuciu <philippe.ciuciu@cea.fr>
#
# Dependencies:
#
# scipy          : >=0.18.0  - required | 1.2.1     installed
# numpy          : >=1.11.0  - required | 1.16.2    installed
# matplotlib     : >=2.0.0   - required | 3.0.3     installed
# future         : >=0.16.0  - required | 0.17.1    installed
# astropy        : ==2.0.8   - required | 2.0.8     installed
# nibabel        : >=2.1.0   - required | 2.4.0     installed
# pyqtgraph      : >=0.10.0  - required | 0.10.0    installed
# progressbar2   : >=3.34.3  - required | ?         installed
# modopt         : >=1.1.5   - required | 1.3.1     installed
# scikit-learn   : >=0.19.1  - required | ?         installed
# pywt           : >=1.0.0   - required | 1.0.2     installed
# pybind11       : >=2.2.4   - required | ?         installed
# pysparse       : >=0.0.1   - required | 0.0.2     installed

# %% [markdown]
# #  Loading input data

# %%
image = get_sample_data("mri-slice-nifti")
original_image_data = np.copy(image.data)
image.data += np.random.randn(*image.shape) * 20.
image.data = image.data.astype(np.complex128)
mask = get_sample_data("mri-mask")

# %%
non_cartesian = True
sparkling = True
opt_results = {}

# %% [markdown]
# # Generate the kspace
# From the 2D brain slice and the acquistion mask, we generate the acquisition measurments, the observed kspace. We then reconstruct the zero order solution.

# %%
# potential path to sparkling trajectory
sparkling_traj_file_path = '../personal_experiments/2019-Mar-01_N512_nc34_ns3073_OS1_decim64_decay2_tau0.75_nrevol1/samples_SPARKLING_N512_nc34x3073_OS1.mat'

# %%
# Generate the subsampled kspace
if non_cartesian:
    if sparkling:
        kspace_loc = scipy.io.loadmat(sparkling_traj_file_path)['samples']
    else:
        kspace_loc = convert_mask_to_locations(mask.data)
    fourier_op = NFFT(samples=kspace_loc, shape=image.shape)
    kspace_data = fourier_op.op(image.data)

    # Zero order solution
    image_rec0 = pysap.Image(data=fourier_op.adj_op(kspace_data), metadata=image.metadata)
else:
    kspace_mask = np.fft.ifftshift(mask.data)
    kspace_loc = convert_mask_to_locations(kspace_mask)
    fourier_op = FFT2(samples=kspace_loc, shape=image.shape)
    kspace_data = fourier_op.op(image.data)

    # Zero order solution
    image_rec0 = pysap.Image(data=fourier_op.adj_op(kspace_data), metadata=image.metadata)
# Out:
# /home/zaccharie/workspace/pysap-mri/mri/reconstruct/fourier.py:172: UserWarning: Samples will be normalized between [-0.5; 0.5[
#   warnings.warn("Samples will be normalized between [-0.5; 0.5[")
# /home/zaccharie/workspace/pysap-mri/mri/reconstruct/utils.py:103: UserWarning: Frequency equal to 0.5 will be put in -0.5
#   warnings.warn("Frequency equal to 0.5 will be put in -0.5")

# %% [markdown]
# # Operators

# %%
nb_scales = 4
wavelet_name = 'db4'
wavelet_id = 24

# %%
# linear_op = Wavelet2(
#     nb_scale=nb_scales,
#     wavelet_name=wavelet_name,
#     padding='periodization',
# )

linear_op = WaveletUD(
    nb_scale=nb_scales,
    wavelet_id=wavelet_id,
    coarse=False,
    set_norm=1.1,
    parallel=False,
)

gradient_op = GradAnalysis2(
    data=kspace_data,
    fourier_op=fourier_op)

# Define the proximity dual/primal operator
# prox_op = LinearCompositionProx(
#     linear_op=linear_op,
#     prox_op=SparseThreshold(Identity(), None, thresh_type="soft"),
# )
prox_op_iterative = LinearCompositionIterativeProx(
    linear_op=linear_op,
    prox_op=SparseThreshold(Identity(), None, thresh_type="soft"),
    max_precision_level=300,
    solver_sigma=10.0,
)
cost_op = None
# Out:
# WARNING: Making input data immutable.

# %% [markdown]
# # FAASTA optimization
# We now want to refine the zero order solution using a FAASTA optimization.

# %%
def objective_cost(x):
    return data_fidelity(x) + sparsity(x)

def sparsity(x):
    return mu * np.sum(np.abs(linear_op.op(x)))

def data_fidelity(x):
    return 0.5 * np.linalg.norm(fourier_op.op(x) - kspace_data)**2

# %%
def nrmse(x):
    return np.linalg.norm(x - original_image_data) / np.mean(original_image_data)

# %%
metrics_ = {
    "cost": {"metric": objective_cost, "mapping": {"x_new": "x"}, "cst_kwargs": {}, "early_stopping": False},
    "nrmse": {"metric": nrmse, "mapping": {"x_new": "x"}, "cst_kwargs": {}, "early_stopping": False},
}

# %%
mu = 15.0

# %%
max_iter = 50
convergence_pot = max_iter >= 500

# %%
# Start the FISTA reconstruction
cost_op = None

x_final_iterative, transform, costs, metrics_iterative = sparse_rec_fista(
    gradient_op=gradient_op,
    linear_op=Identity(),
    prox_op=prox_op_iterative,
    cost_op=cost_op,
    xi_restart=0.96,
    s_greedy=1.1,
    mu=mu,
    restart_strategy='greedy',
    pov='analysis',
    iterative_prox=True,
    cost_function=objective_cost,
    max_nb_of_iter=max_iter,
    metrics=metrics_,
    metric_call_period=5,
    verbose=1,
    adaptative_precision=True,
    precision_increase_rate=1.2,
    initial_precision_level=5,
)
image_rec_iterative = pysap.Image(data=np.abs(x_final_iterative))
# Out:
#   _____             ____     _____      _
#  |" ___|    ___    / __"| u |_ " _| U  /"\  u
# U| |_  u   |_"_|  <\___ \/    | |    \/ _ \/
# \|  _|/     | |    u___) |   /| |\   / ___ \\
#  |_|      U/| |\u  |____/>> u |_|U  /_/   \_\\
#  )(\\\,-.-,_|___|_,-.)(  (__)_// \\\_  \\\    >>
# (__)(_/ \_)-' '-(_/(__)    (__) (__)(__)  (__)
#
#  - mu:  15.0
#  - lipschitz constant:  95.5108226538346
#  - data:  (512, 512)
#  - max iterations:  50
#  - image variable shape:  (512, 512)
#  - alpha variable shape:  (512, 512)
# ----------------------------------------
# Starting optimization...
# WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
# N/A% (0 of 50) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#   2% (1 of 50) |                         | Elapsed Time: 0:00:04 ETA:   0:03:53WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#   4% (2 of 50) |#                        | Elapsed Time: 0:00:09 ETA:   0:03:51WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#   6% (3 of 50) |#                        | Elapsed Time: 0:00:14 ETA:   0:03:44WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#   8% (4 of 50) |##                       | Elapsed Time: 0:00:19 ETA:   0:03:45WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#  10% (5 of 50) |##                       | Elapsed Time: 0:00:24 ETA:   0:03:47WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#  12% (6 of 50) |###                      | Elapsed Time: 0:00:29 ETA:   0:03:25WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:02 Time:  0:00:02
#  14% (7 of 50) |###                      | Elapsed Time: 0:00:33 ETA:   0:03:21WARNING: Making input data immutable.
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:03 Time:  0:00:03
#  16% (8 of 50) |####                     | Elapsed Time: 0:00:38 ETA:   0:03:33WARNING: Making input data immutable.
# 100% (6 of 6) |##########################| Elapsed Time: 0:00:03 Time:  0:00:03
#  18% (9 of 50) |####                     | Elapsed Time: 0:00:44 ETA:   0:03:57WARNING: Making input data immutable.
# 100% (6 of 6) |##########################| Elapsed Time: 0:00:04 Time:  0:00:04
#
ARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:05 Time:  0:00:05
#  72% (36 of 50) |#################       | Elapsed Time: 0:03:59 ETA:   0:01:50WARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:06 Time:  0:00:06
#  74% (37 of 50) |#################       | Elapsed Time: 0:04:07 ETA:   0:01:49WARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:05 Time:  0:00:05
#  76% (38 of 50) |##################      | Elapsed Time: 0:04:15 ETA:   0:01:32WARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:05 Time:  0:00:05
#  78% (39 of 50) |##################      | Elapsed Time: 0:04:23 ETA:   0:01:26WARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:04 Time:  0:00:04
#  80% (40 of 50) |###################     | Elapsed Time: 0:04:30 ETA:   0:01:14WARNING: Making input data immutable.
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:05 Time:  0:00:05
#  82% (41 of 50) |###################     | Elapsed Time: 0:04:37 ETA:   0:01:05WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:06 Time:  0:00:06
#  84% (42 of 50) |####################    | Elapsed Time: 0:04:47 ETA:   0:01:12WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:06 Time:  0:00:06
#  86% (43 of 50) |####################    | Elapsed Time: 0:04:56 ETA:   0:01:03WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
#  88% (44 of 50) |#####################   | Elapsed Time: 0:05:05 ETA:   0:00:54WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
#  90% (45 of 50) |#####################   | Elapsed Time: 0:05:14 ETA:   0:00:47WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
#  92% (46 of 50) |######################  | Elapsed Time: 0:05:24 ETA:   0:00:37WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
#  94% (47 of 50) |######################  | Elapsed Time: 0:05:33 ETA:   0:00:27WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
#  96% (48 of 50) |####################### | Elapsed Time: 0:05:42 ETA:   0:00:19WARNING: Making input data immutable.
# 100% (10 of 10) |########################| Elapsed Time: 0:00:07 Time:  0:00:07
# 100% (50 of 50) |########################| Elapsed Time: 0:05:52 Time:  0:05:52
#  - converged:  False
# Done.
# Execution time:  554.1396849999996  seconds
# ----------------------------------------

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 5), sharex=True, sharey=True)
im1 = axs[0].imshow(np.abs(x_final_iterative), cmap='gray')
axs[0].set_title("Iterative prox")
axs[1].imshow(np.abs(original_image_data), cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure()
plt.plot(np.log10(np.array(metrics_iterative['nrmse']['values'])), label='NRMSE iterative')
plt.title('Final nrmse {}'.format(metrics_iterative['nrmse']['values'][-1]))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(np.log10(np.array(metrics_iterative['cost']['values'])), label='cost iterative')
plt.title('Final cost {}'.format(metrics_iterative['cost']['values'][-1]))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
